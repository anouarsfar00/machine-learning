# %% [markdown]
# # Préparation des données

# %%
import pandas as pd  # Bibliothèque pour manipuler des données
import numpy as np #calcul matriciel et vectoriel
import matplotlib.pyplot as plt # Bibliothèque de visualisation 
import seaborn as sns # Bibliothèque de visualisation basée sur matplotlib

# %%
dataset=pd.read_excel('C:/Users/21621/Desktop/Projet PANAL/CreditBank.xlsx')
# Out:
# C:\Users\21621\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# C:\Users\21621\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)

# %%
dataset
# Out:
#      revenuAnnuel  autreRevenu      salaire   age  anneeTravaillee  \
# 0         29921.0            0  2493.416667  51.0             10.0
# 1         22912.0          530  1379.333333  32.0              5.0
# 2         15780.0            0  1315.000000  30.0              5.0
# 3         31293.0          848  1759.750000  29.0              5.0
# 4         14312.0            0  1192.666667  36.0             10.0
# ..            ...          ...          ...   ...              ...
# 167        9807.0            0   817.250000  62.0             20.0
# 168       15682.0            0  1306.833333  22.0              2.0
# 169        9122.0            0   760.166667  25.0              2.0
# 170        9703.0            0   808.583333  31.0              5.0
# 171       17936.0            0  1494.666667  45.0              2.0
#
#      nbDernierCreditRefuse  nbDernierCreditQccepte  PersonnesEnCharge  \
# 0                      0.0                     1.0                1.0
# ...

# %%
dataset.head()
# Out:
#    revenuAnnuel  autreRevenu      salaire   age  anneeTravaillee  \
# 0       29921.0            0  2493.416667  51.0             10.0
# 1       22912.0          530  1379.333333  32.0              5.0
# 2       15780.0            0  1315.000000  30.0              5.0
# 3       31293.0          848  1759.750000  29.0              5.0
# 4       14312.0            0  1192.666667  36.0             10.0
#
#    nbDernierCreditRefuse  nbDernierCreditQccepte  PersonnesEnCharge  \
# 0                    0.0                     1.0                1.0
# 1                    3.0                     2.0                1.0
# 2                    3.0                     0.0                2.0
# 3                    2.0                     2.0                0.0
# 4                    2.0                     2.0                2.0
#
#    RevenuNetMoyen  nbVoitures catgSocialePro statutSocial  \
# 0      831.138889           2        Titular       Single
# ...

# %%
dataset.tail()
# Out:
#      revenuAnnuel  autreRevenu      salaire   age  anneeTravaillee  \
# 167        9807.0            0   817.250000  62.0             20.0
# 168       15682.0            0  1306.833333  22.0              2.0
# 169        9122.0            0   760.166667  25.0              2.0
# 170        9703.0            0   808.583333  31.0              5.0
# 171       17936.0            0  1494.666667  45.0              2.0
#
#      nbDernierCreditRefuse  nbDernierCreditQccepte  PersonnesEnCharge  \
# 167                    1.0                     2.0                2.0
# 168                    4.0                     2.0                1.0
# 169                    3.0                     0.0                3.0
# 170                    2.0                     1.0                1.0
# 171                    1.0                     0.0                2.0
#
#      RevenuNetMoyen  nbVoitures catgSocialePro statutSocial  \
# 167      272.416667           1        Retired      Married
# ...

# %%
dataset.describe() #Afficher les statistiques
# Out:
#        revenuAnnuel  autreRevenu      salaire         age  anneeTravaillee  \
# count    172.000000   172.000000   171.000000  171.000000       171.000000
# mean   19074.761628    84.581395  1513.783138   42.192982         6.321637
# std     6915.620548   214.930968   511.367373   14.823001         5.414202
# min        0.000000     0.000000   701.500000   20.000000         1.000000
# 25%    13953.000000     0.000000  1087.166667   29.500000         2.000000
# 50%    17984.500000     0.000000  1478.083333   41.000000         5.000000
# 75%    25091.500000     0.000000  1956.666667   53.500000        10.000000
# max    37536.000000   871.000000  2493.416667   77.000000        20.000000
#
#        nbDernierCreditRefuse  nbDernierCreditQccepte  PersonnesEnCharge  \
# count             171.000000              171.000000         170.000000
# mean                2.122807                1.040936           1.858824
# std                 1.329354                0.814261           1.360064
# ...

# %%
dataset.shape
# Out:
# (172, 15)

# %%
dataset.info() #Datatypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   revenuAnnuel            172 non-null    float64
#  1   autreRevenu             172 non-null    int64
#  2   salaire                 171 non-null    float64
#  3   age                     171 non-null    float64
#  4   anneeTravaillee         171 non-null    float64
#  5   nbDernierCreditRefuse   171 non-null    float64
#  6   nbDernierCreditQccepte  171 non-null    float64
#  7   PersonnesEnCharge       170 non-null    float64
#  8   RevenuNetMoyen          171 non-null    float64
#  9   nbVoitures              172 non-null    int64
#  10  catgSocialePro          171 non-null    object
#  11  statutSocial            169 non-null    object
#  12  Residence               170 non-null    object
#  13  secteurTravail          170 non-null    object
# ...

# %%
dataset.dtypes
# Out:
# revenuAnnuel              float64
# autreRevenu                 int64
# salaire                   float64
# age                       float64
# anneeTravaillee           float64
# nbDernierCreditRefuse     float64
# nbDernierCreditQccepte    float64
# PersonnesEnCharge         float64
# RevenuNetMoyen            float64
# nbVoitures                  int64
# catgSocialePro             object
# statutSocial               object
# Residence                  object
# secteurTravail             object
# Decision                   object
# dtype: object

# %%
dataset.columns
# Out:
# Index(['revenuAnnuel', 'autreRevenu', 'salaire', 'age', 'anneeTravaillee',
#        'nbDernierCreditRefuse', 'nbDernierCreditQccepte', 'PersonnesEnCharge',
#        'RevenuNetMoyen', 'nbVoitures', 'catgSocialePro', 'statutSocial',
#        'Residence', 'secteurTravail', 'Decision'],
#       dtype='object')

# %%
dataset.describe()
# Out:
#        revenuAnnuel  autreRevenu      salaire         age  anneeTravaillee  \
# count    172.000000   172.000000   171.000000  171.000000       171.000000
# mean   19074.761628    84.581395  1513.783138   42.192982         6.321637
# std     6915.620548   214.930968   511.367373   14.823001         5.414202
# min        0.000000     0.000000   701.500000   20.000000         1.000000
# 25%    13953.000000     0.000000  1087.166667   29.500000         2.000000
# 50%    17984.500000     0.000000  1478.083333   41.000000         5.000000
# 75%    25091.500000     0.000000  1956.666667   53.500000        10.000000
# max    37536.000000   871.000000  2493.416667   77.000000        20.000000
#
#        nbDernierCreditRefuse  nbDernierCreditQccepte  PersonnesEnCharge  \
# count             171.000000              171.000000         170.000000
# mean                2.122807                1.040936           1.858824
# std                 1.329354                0.814261           1.360064
# ...

# %%
dataset_nullity = dataset.isnull()

# %%
dataset_nullity.head()
# Out:
#    revenuAnnuel  autreRevenu  salaire    age  anneeTravaillee  \
# 0         False        False    False  False            False
# 1         False        False    False  False            False
# 2         False        False    False  False            False
# 3         False        False    False  False            False
# 4         False        False    False  False            False
#
#    nbDernierCreditRefuse  nbDernierCreditQccepte  PersonnesEnCharge  \
# 0                  False                   False              False
# 1                  False                   False              False
# 2                  False                   False              False
# 3                  False                   False              False
# 4                  False                   False              False
#
#    RevenuNetMoyen  nbVoitures  catgSocialePro  statutSocial  Residence  \
# 0           False       False           False         False      False
# ...

# %%
dataset['Decision'].replace(['Refused', 'Accepted','Tolerated'],
                        [0, 1,2], inplace=True)

# %%
dataset
# Out:
#      revenuAnnuel  autreRevenu      salaire   age  anneeTravaillee  \
# 0         29921.0            0  2493.416667  51.0             10.0
# 1         22912.0          530  1379.333333  32.0              5.0
# 2         15780.0            0  1315.000000  30.0              5.0
# 3         31293.0          848  1759.750000  29.0              5.0
# 4         14312.0            0  1192.666667  36.0             10.0
# ..            ...          ...          ...   ...              ...
# 167        9807.0            0   817.250000  62.0             20.0
# 168       15682.0            0  1306.833333  22.0              2.0
# 169        9122.0            0   760.166667  25.0              2.0
# 170        9703.0            0   808.583333  31.0              5.0
# 171       17936.0            0  1494.666667  45.0              2.0
#
#      nbDernierCreditRefuse  nbDernierCreditQccepte  PersonnesEnCharge  \
# 0                      0.0                     1.0                1.0
# ...

# %%
dataset_nullity.sum()
# Out:
# revenuAnnuel              0
# autreRevenu               0
# salaire                   1
# age                       1
# anneeTravaillee           1
# nbDernierCreditRefuse     1
# nbDernierCreditQccepte    1
# PersonnesEnCharge         2
# RevenuNetMoyen            1
# nbVoitures                0
# catgSocialePro            1
# statutSocial              3
# Residence                 2
# secteurTravail            2
# Decision                  0
# dtype: int64

# %% [markdown]
# # visualisation des données

# %%
sns.set(style='ticks',palette='deep', font_scale=1.1)
plt.hist(dataset['age'], bins =5, color='b', alpha=0.8)
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Histogram of age")
plt.show()

# %%
dataset.hist(figsize=(20,20))
plt.show()

# %%
sns.countplot(x ='Decision', data = dataset,palette="Blues")
plt.show()

# %%
sns.boxplot(x=dataset['Decision'], y=dataset['age'],palette="Blues")
plt.show()

# %%
sns.kdeplot (data=dataset, x='revenuAnnuel',hue='Decision', multiple="stack",)  #palette="Blues"
plt.show()

# %%
sns.boxplot(y="age",data=dataset)
# Out:
# <AxesSubplot:ylabel='age'>

# %%
sns.boxplot(y="RevenuNetMoyen",data=dataset)
# Out:
# <AxesSubplot:ylabel='RevenuNetMoyen'>

# %%
dataset_corr = dataset.corr()
dataset_corr
plt.figure(figsize=(30, 30))
sns.heatmap(dataset_corr, cbar = True,  square = True, annot=True, fmt= '.2f',annot_kws={'size': 15},cmap= 'coolwarm')
plt.title('Correlation between features');

# %%
datasetN=dataset.dropna()
datasetN
# Out:
#      revenuAnnuel  autreRevenu      salaire   age  anneeTravaillee  \
# 0         29921.0            0  2493.416667  51.0             10.0
# 1         22912.0          530  1379.333333  32.0              5.0
# 2         15780.0            0  1315.000000  30.0              5.0
# 3         31293.0          848  1759.750000  29.0              5.0
# 4         14312.0            0  1192.666667  36.0             10.0
# ..            ...          ...          ...   ...              ...
# 167        9807.0            0   817.250000  62.0             20.0
# 168       15682.0            0  1306.833333  22.0              2.0
# 169        9122.0            0   760.166667  25.0              2.0
# 170        9703.0            0   808.583333  31.0              5.0
# 171       17936.0            0  1494.666667  45.0              2.0
#
#      nbDernierCreditRefuse  nbDernierCreditQccepte  PersonnesEnCharge  \
# 0                      0.0                     1.0                1.0
# ...

# %%
dataset_nullity = datasetN.isnull()
dataset_nullity.sum()
# Out:
# revenuAnnuel              0
# autreRevenu               0
# salaire                   0
# age                       0
# anneeTravaillee           0
# nbDernierCreditRefuse     0
# nbDernierCreditQccepte    0
# PersonnesEnCharge         0
# RevenuNetMoyen            0
# nbVoitures                0
# catgSocialePro            0
# statutSocial              0
# Residence                 0
# secteurTravail            0
# Decision                  0
# dtype: int64

# %% [markdown]
# # segmentation des clients de la banque

# %%
x=datasetN.iloc[:,1:10] 
y=datasetN.iloc[:,14:15]

# %%
x.head()
# Out:
#    autreRevenu      salaire   age  anneeTravaillee  nbDernierCreditRefuse  \
# 0            0  2493.416667  51.0             10.0                    0.0
# 1          530  1379.333333  32.0              5.0                    3.0
# 2            0  1315.000000  30.0              5.0                    3.0
# 3          848  1759.750000  29.0              5.0                    2.0
# 4            0  1192.666667  36.0             10.0                    2.0
#
#    nbDernierCreditQccepte  PersonnesEnCharge  RevenuNetMoyen  nbVoitures
# 0                     1.0                1.0      831.138889           2
# 1                     2.0                1.0      636.444444           1
# 2                     0.0                2.0      438.333333           0
# 3                     2.0                0.0      869.250000           1
# 4                     2.0                2.0      397.555556           1

# %%
y.head()
# Out:
#     Decision
# 0   Accepted
# 1   Accepted
# 2    Refused
# 3   Accepted
# 4  Tolerated

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.frame.DataFrame

# %%
x=x.values
y=y.values

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x[0:13,:]
# Out:
# array([[0.00000000e+00, 2.49341667e+03, 5.10000000e+01, 1.00000000e+01,
#         0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 8.31138889e+02,
#         2.00000000e+00],
#        [5.30000000e+02, 1.37933333e+03, 3.20000000e+01, 5.00000000e+00,
#         3.00000000e+00, 2.00000000e+00, 1.00000000e+00, 6.36444444e+02,
#         1.00000000e+00],
#        [0.00000000e+00, 1.31500000e+03, 3.00000000e+01, 5.00000000e+00,
#         3.00000000e+00, 0.00000000e+00, 2.00000000e+00, 4.38333333e+02,
#         0.00000000e+00],
#        [8.48000000e+02, 1.75975000e+03, 2.90000000e+01, 5.00000000e+00,
#         2.00000000e+00, 2.00000000e+00, 0.00000000e+00, 8.69250000e+02,
#         1.00000000e+00],
#        [0.00000000e+00, 1.19266667e+03, 3.60000000e+01, 1.00000000e+01,
#         2.00000000e+00, 2.00000000e+00, 2.00000000e+00, 3.97555556e+02,
#         1.00000000e+00],
#        [0.00000000e+00, 1.86508333e+03, 4.90000000e+01, 2.00000000e+00,
# ...

# %%
from sklearn.model_selection import train_test_split #t importi train_test_split elli mawjouda fl sklearn.model_selection
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0) #la partie test représente 20% hedheka aalch 0.2 
# random_state

# %%
print('x_train shape',x_train.shape) #taille de la partie x_train 
print('x_test shape',x_test.shape) #taille de la partie x_test 
print('y_train shape',y_train.shape) #taille de la partie y_train 
print('y_test shape',y_test.shape) #taille de la partie x_test
# Out:
# x_train shape (124, 9)
# x_test shape (32, 9)
# y_train shape (124, 1)
# y_test shape (32, 1)

# %%
x_train
# Out:
# array([[0.00000000e+00, 2.40516667e+03, 3.30000000e+01, ...,
#         1.00000000e+00, 8.01722222e+02, 0.00000000e+00],
#        [0.00000000e+00, 8.83500000e+02, 3.10000000e+01, ...,
#         0.00000000e+00, 2.94500000e+02, 0.00000000e+00],
#        [0.00000000e+00, 1.35925000e+03, 3.60000000e+01, ...,
#         2.00000000e+00, 4.53083333e+02, 1.00000000e+00],
#        ...,
#        [0.00000000e+00, 2.42075000e+03, 4.90000000e+01, ...,
#         4.00000000e+00, 8.06916667e+02, 1.00000000e+00],
#        [0.00000000e+00, 1.80675000e+03, 4.50000000e+01, ...,
#         3.00000000e+00, 6.02250000e+02, 2.00000000e+00],
#        [0.00000000e+00, 7.28166667e+02, 3.10000000e+01, ...,
#         1.00000000e+00, 2.42722222e+02, 1.00000000e+00]])

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()

# %%
logreg.fit(x_train, y_train)
# Out:
# C:\Users\21621\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\21621\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
log_predicted= logreg.predict(x_test)
logreg_score = round(logreg.score(x_train, y_train) * 100, 2)
logreg_score_test = round(logreg.score(x_test, y_test) * 100, 2)

# %%
#Equation coefficient and Intercept
from sklearn.metrics import classification_report,confusion_matrix
print('Logistic Regression Training Score: \n', logreg_score)
print('Logistic Regression Test Score: \n', logreg_score_test)
print('Coefficient: \n', logreg.coef_)
print('Intercept: \n', logreg.intercept_)
print('Accuracy: \n', accuracy_score(y_test,log_predicted))
print('Confusion Matrix: \n', confusion_matrix(y_test,log_predicted))
print('Classification Report: \n', classification_report(y_test,log_predicted))
# Out:
# Logistic Regression Training Score:
#  62.9
# Logistic Regression Test Score:
#  62.5
# Coefficient:
#  [[ 3.10730013e-03  8.07063122e-04 -1.64629900e-02  3.80297775e-02
#   -3.41779297e-01  9.19269579e-02 -2.51123846e-01  1.30478775e-03
#   -1.19463269e-01]
#  [-8.07974800e-04 -1.13306890e-03  3.39819870e-02 -4.10199766e-02
#    3.68743931e-01 -1.44197832e-01  1.17286545e-01 -6.47014566e-04
#    7.88949752e-02]
#  [-2.29932533e-03  3.26005775e-04 -1.75189970e-02  2.99019911e-03
#   -2.69646339e-02  5.22708743e-02  1.33837301e-01 -6.57773186e-04
#    4.05682934e-02]]
# Intercept:
#  [-0.09813771  0.08403848  0.01409923]
# Accuracy:
#  0.625
# Confusion Matrix:
#  [[ 5  1  1]
#  [ 6 15  0]
#  [ 2  2  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#     Accepted       0.38      0.71      0.50         7
#      Refused       0.83      0.71      0.77        21
#    Tolerated       0.00      0.00      0.00         4
#
# ...

# %%
sns.heatmap(confusion_matrix(y_test,log_predicted),annot=True,fmt="d")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Gaussian NB

# %%
from sklearn.naive_bayes import GaussianNB
gaussian = GaussianNB()
gaussian.fit(x_train, y_train)
# Out:
# C:\Users\21621\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB()

# %%
gauss_predicted = gaussian.predict(x_test)

# %%
gauss_score = round(gaussian.score(x_train, y_train) * 100, 2)
gauss_score_test = round(gaussian.score(x_test, y_test) * 100, 2)
print('Gaussian Score: \n', gauss_score)
print('Gaussian Test Score: \n', gauss_score_test)
print('Accuracy: \n', accuracy_score(y_test, gauss_predicted))
print(confusion_matrix(y_test,gauss_predicted))
print(classification_report(y_test,gauss_predicted))
# Out:
# Gaussian Score:
#  70.16
# Gaussian Test Score:
#  81.25
# Accuracy:
#  0.8125
# [[ 7  0  0]
#  [ 1 18  2]
#  [ 2  1  1]]
#               precision    recall  f1-score   support
#
#     Accepted       0.70      1.00      0.82         7
#      Refused       0.95      0.86      0.90        21
#    Tolerated       0.33      0.25      0.29         4
#
#     accuracy                           0.81        32
#    macro avg       0.66      0.70      0.67        32
# weighted avg       0.82      0.81      0.81        32

# %%
sns.heatmap(confusion_matrix(y_test,gauss_predicted),annot=True,fmt="d")
# Out:
# <AxesSubplot:>

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, BaggingClassifier
random_forest = RandomForestClassifier(max_depth=3,n_estimators=56,criterion='entropy')
random_forest.fit(x_train, y_train)
# Out:
# C:\Users\21621\AppData\Local\Temp\ipykernel_13720\4106889308.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   random_forest.fit(x_train, y_train)
# RandomForestClassifier(criterion='entropy', max_depth=3, n_estimators=56)

# %% [markdown]
# # random_forest

# %%
rf_predicted = random_forest.predict(x_test)
random_forest_score = round(random_forest.score(x_train, y_train) * 100, 2)
random_forest_score_test = round(random_forest.score(x_test, y_test) * 100, 2)
print('Random Forest Score: \n', random_forest_score)
print('Random Forest Test Score: \n', random_forest_score_test)
print('Accuracy: \n', accuracy_score(y_test,rf_predicted))
print(confusion_matrix(y_test,rf_predicted))
print(classification_report(y_test,rf_predicted))
# Out:
# Random Forest Score:
#  83.87
# Random Forest Test Score:
#  84.38
# Accuracy:
#  0.84375
# [[ 6  1  0]
#  [ 1 20  0]
#  [ 1  2  1]]
#               precision    recall  f1-score   support
#
#     Accepted       0.75      0.86      0.80         7
#      Refused       0.87      0.95      0.91        21
#    Tolerated       1.00      0.25      0.40         4
#
#     accuracy                           0.84        32
#    macro avg       0.87      0.69      0.70        32
# weighted avg       0.86      0.84      0.82        32
